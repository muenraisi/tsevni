# %%
import warnings
warnings.filterwarnings("ignore")

from jqdatasdk import *
auth('18810883096', 'Ww19930921')
# 查询是否连接成功
is_auth = is_auth()
# Out:
# 提示：当前环境pandas版本为0.25，get_price与get_fundamentals_continuously接口panel参数将固定为False
# 注意：0.25以上版本pandas不支持panel，如使用该数据结构和相关函数请注意修改
# auth success

# %%
#兖洲煤业 600188
get_industry("000002.XSHE", date=None)
# Out:
# {'000002.XSHE': {'sw_l1': {'industry_code': '801180', 'industry_name': '房地产I'},
#   'sw_l2': {'industry_code': '801181', 'industry_name': '房地产开发II'},
#   'sw_l3': {'industry_code': '851811', 'industry_name': '房地产开发III'},
#   'zjw': {'industry_code': 'K70', 'industry_name': '房地产业'},
#   'jq_l2': {'industry_code': 'HY509', 'industry_name': '房地产开发指数'},
#   'jq_l1': {'industry_code': 'HY011', 'industry_name': '房地产指数'}}}

# %%
# 煤炭行业的成分股
sw_id='801180'
stocks = get_industry_stocks(sw_id)
print(stocks)
# Out:
# ['000002.XSHE', '000006.XSHE', '000011.XSHE', '000014.XSHE', '000029.XSHE', '000031.XSHE', '000036.XSHE', '000042.XSHE', '000046.XSHE', '000056.XSHE', '000069.XSHE', '000090.XSHE', '000402.XSHE', '000502.XSHE', '000506.XSHE', '000514.XSHE', '000517.XSHE', '000537.XSHE', '000540.XSHE', '000558.XSHE', '000560.XSHE', '000573.XSHE', '000608.XSHE', '000609.XSHE', '000615.XSHE', '000616.XSHE', '000620.XSHE', '000631.XSHE', '000656.XSHE', '000667.XSHE', '000668.XSHE', '000671.XSHE', '000679.XSHE', '000691.XSHE', '000718.XSHE', '000732.XSHE', '000736.XSHE', '000797.XSHE', '000809.XSHE', '000838.XSHE', '000863.XSHE', '000897.XSHE', '000909.XSHE', '000918.XSHE', '000926.XSHE', '000961.XSHE', '000965.XSHE', '000981.XSHE', '001914.XSHE', '001979.XSHE', '002016.XSHE', '002133.XSHE', '002146.XSHE', '002147.XSHE', '002208.XSHE', '002244.XSHE', '002285.XSHE', '002305.XSHE', '002314.XSHE', '002377.XSHE', '002968.XSHE', '600007.XSHG', '600048.XSHG', '600064.XSHG', '600067.XSHG', '600077.XSHG', '600082.XSHG', '600094.XSHG', '600159.XSHG', '600162.XSHG', '600173.XSHG', '600177.XSHG', '600185.XSHG', '600208.XSHG', '600215.XSHG', '600223.XSHG', '600225.XSHG', '600239.XSHG', '600246.XSHG', '600266.XSHG', '600322.XSHG', '600325.XSHG', '600340.XSHG', '600376.XSHG', '600383.XSHG', '600393.XSHG', '600463.XSHG', '600466.XSHG', '600503.XSHG', '600510.XSHG', '600515.XSHG', '600533.XSHG', '600565.XSHG', '600568.XSHG', '600604.XSHG', '600606.XSHG', '600622.XSHG', '600638.XSHG', '600639.XSHG', '600641.XSHG', '600647.XSHG', '600648.XSHG', '600649.XSHG', '600657.XSHG', '600658.XSHG', '600663.XSHG', '600665.XSHG', '600675.XSHG', '600683.XSHG', '600684.XSHG', '600692.XSHG', '600708.XSHG', '600716.XSHG', '600724.XSHG', '600732.XSHG', '600736.XSHG', '600743.XSHG', '600748.XSHG', '600773.XSHG', '600791.XSHG', '600807.XSHG', '600823.XSHG', '600848.XSHG', '600890.XSHG', '600895.XSHG', '601155.XSHG', '601512.XSHG', '601588.XSHG', '603506.XSHG']

# %%
stock_name={}
for stock in stocks:
    stock_name[stock]=get_security_info(stock).display_name

# %%
# 获取一支股票
start_date="2020-08-22"
end_date="2020-10-20"

df_dict={}
for stock in stocks:
    df_dict[stock] = get_price(stock, start_date=start_date, end_date=end_date,fq="pre") # 获得000001.XSHG的2015年12月1号14:00-2015年12月2日12:00的分钟数据
print("load data")
# Out:
# load data

# %%
#coding:utf-8
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号
#有中文出现的情况，需要u'内容'

import numpy as np

x = np.linspace(0, 1, 100)
number = len(stocks)
cmap = plt.get_cmap('rainbow')
colors = [cmap(i) for i in np.linspace(0, 1, number)]

plt.rcParams['figure.figsize'] = (20.0, 10.0) # 显示大小
for i, stock in enumerate(stocks):
    df=df_dict[stock].dropna()
    plt.plot(df['close']/df['close'][0],color=colors[i],label=stock_name[stock])
    
df_indus = finance.run_query(
    query(finance.SW1_DAILY_PRICE).filter(
        finance.SW1_DAILY_PRICE.code == sw_id,
        finance.SW1_DAILY_PRICE.date >= start_date,
        finance.SW1_DAILY_PRICE.date <= end_date).order_by(
        finance.SW1_DAILY_PRICE.date.desc()).limit(1000))
plt.plot(list(df_dict[stock].T),df_indus['close']/df_indus['close'].values[-1],marker='+', linestyle='--', linewidth=1, markersize=4,label="steel")
plt.legend()

# %%
import pandas as pd
#显示所有列
pd.set_option('display.max_columns', None)
#显示所有行
pd.set_option('display.max_rows', None)
#设置value的显示长度为100，默认为50
pd.set_option('max_colwidth',100)
stock_return={}
for stock in stocks:
    df=df_dict[stock].dropna()
    stock_return[stock]=(df['close']/df['close'][0]).values[-1]
df_stock=pd.DataFrame({'name':stock_name,
       'return':stock_return})
df_stock.sort_values(by="return",inplace=True,ascending=False)
print(df_indus["close"].values[0]/df_indus["close"].values[-1])
print(df_stock)
# Out:
# 0.8861509336977439
#               name    return
# 001914.XSHE   招商积余  3.353546
# 600223.XSHG   鲁商发展  3.256724
# 000011.XSHE   深物业A  2.576609
# 600641.XSHG   万业企业  2.558733
# 002968.XSHE    新大正  2.555076
# 600185.XSHG   格力地产  2.320721
# 600732.XSHG   爱旭股份  2.153090
# 600246.XSHG   万通发展  1.817391
# 002208.XSHE   合肥城建  1.655329
# 000090.XSHE   天健集团  1.635860
# 603506.XSHG   南都物业  1.411010
# 002314.XSHE   南山控股  1.370370
# 000006.XSHE   深振业A  1.329618
# 000656.XSHE   金科股份  1.300140
# 000668.XSHE   荣丰控股  1.262831
# 600510.XSHG    黑牡丹  1.260745
# 000667.XSHE   美好置业  1.227586
# 600048.XSHG   保利地产  1.220588
# 600383.XSHG   金地集团  1.169591
# 000691.XSHE   亚太实业  1.146568
# 600895.XSHG   张江高科  1.120397
# 600177.XSHG    雅戈尔  1.118812
# 600515.XSHG   海航基础  1.117560
# 600173.XSHG   卧龙地产  1.105578
# 000014.XSHE   沙河股份  1.094276
# 600606.XSHG   绿地控股  1.093445
# 600724.XSHG   宁波富达  1.089157
# 000961.XSHE   中南建设  1.086595
# 600077.XSHG   宋都股份  1.044693
# 000736.XSHE   中交地产  1.029957
# 600658.XSHG    电子城  1.027732
# 600890.XSHG   中房股份  1.017219
# 000029.XSHE   深深房A  1.000000
# 000718.XSHE   苏宁环球  0.980501
# 600064.XSHG   南京高科  0.980410
# 600791.XSHG   京能置业  0.966797
# 600533.XSHG   栖霞建设  0.965241
# 000909.XSHE   数源科技  0.963768
# 600639.XSHG   浦东金桥  0.949109
# 000069.XSHE   华侨城A  0.946891
# 000863.XSHE   三湘印象  0.946667
# 000671.XSHE    阳光城  0.936376
# 000537.XSHE   广宇发展  0.931793
# 600007.XSHG   中国国贸  0.931546
# 600823.XSHG   世茂股份  0.911523
# 600657.XSHG   信达地产  0.911025
# 000036.XSHE   华联控股  0.905222
# 002244.XSHE   滨江集团  0.899408
# 600463.XSHG   空港股份  0.896478
# 600807.XSHG   济南高新  0.896014
# 600239.XSHG   云南城投  0.894068
# 000002.XSHE    万科A  0.893420
# 600208.XSHG   新湖中宝  0.891821
# 601155.XSHG   新城控股  0.880589
# 600665.XSHG    天地源  0.879808
# 600325.XSHG   华发股份  0.879353
# 600647.XSHG   同达创业  0.874855
# 000897.XSHE   津滨发展  0.870849
# 000573.XSHE   粤宏远A  0.870620
# 601512.XSHG   中新集团  0.868228
# 000631.XSHE   顺发恒业  0.860000
# 000616.XSHE   海航投资  0.857534
# 600683.XSHG   京投发展  0.845304
# 000609.XSHE   中迪投资  0.842647
# 600663.XSHG    陆家嘴  0.837037
# 600675.XSHG   中华企业  0.828343
# 000620.XSHE    新华联  0.826360
# 000402.XSHE    金融街  0.825877
# 000031.XSHE    大悦城  0.825513
# 600162.XSHG   香江控股  0.822222
# 600773.XSHG   西藏城投  0.813137
# 600159.XSHG   大龙地产  0.803738
# 002146.XSHE   荣盛发展  0.803134
# 001979.XSHE   招商蛇口  0.802381
# 601588.XSHG   北辰实业  0.800000
# 000965.XSHE   天保基建  0.795100
# 600692.XSHG   亚通股份  0.792179
# 000506.XSHE   中润资源  0.791284
# 000797.XSHE   中国武夷  0.791045
# 000560.XSHE   我爱我家  0.790909
# 600503.XSHG   华丽家族  0.787992
# 600393.XSHG   粤泰股份  0.787234
# 000517.XSHE   荣安地产  0.785498
# 600716.XSHG   凤凰股份  0.784200
# 600466.XSHG   蓝光发展  0.781575
# 002133.XSHE   广宇集团  0.779661
# 000042.XSHE   中洲控股  0.777778
# 600743.XSHG   华远地产  0.768421
# 002285.XSHE    世联行  0.768352
# 600067.XSHG   冠城大通  0.766000
# 600266.XSHG   城建发展  0.764045
# 600376.XSHG   首开股份  0.749721
# 600649.XSHG   城投控股  0.746173
# 600684.XSHG   珠江实业  0.744597
# 002016.XSHE   世荣兆业  0.739479
# 000679.XSHE  *ST友谊  0.738095
# 000926.XSHE   福星股份  0.734536
# 600340.XSHG   华夏幸福  0.734322
# 002305.XSHE   南国置业  0.727794
# 000502.XSHE   绿景控股  0.723014
# 600638.XSHG    新黄浦  0.720114
# 000540.XSHE   中天金融  0.715415
# 600322.XSHG   天房发展  0.705426
# 000809.XSHE   铁岭新城  0.704969
# 002377.XSHE   国创高新  0.700499
# 600082.XSHG   海泰发展  0.689850
# 600648.XSHG    外高桥  0.677051
# 600848.XSHG   上海临港  0.663805
# 600604.XSHG   市北高新  0.660455
# 600565.XSHG   迪马股份  0.650549
# 000838.XSHE   财信发展  0.649412
# 000558.XSHE   莱茵体育  0.647332
# 600622.XSHG   光大嘉宝  0.646450
# 600736.XSHG   苏州高新  0.641115
# 000514.XSHE    渝开发  0.634259
# 000918.XSHE    嘉凯城  0.631717
# 000608.XSHE   阳光股份  0.630286
# 600094.XSHG    大名城  0.627244
# 000615.XSHE   京汉股份  0.625714
# 600215.XSHG  *ST经开  0.593088
# 000046.XSHE   泛海控股  0.569128
# 000056.XSHE   皇庭国际  0.569014
# 000732.XSHE   泰禾集团  0.557054
# 600748.XSHG   上实发展  0.515640
# 600708.XSHG   光明地产  0.513937
# 002147.XSHE  *ST新光  0.475645
# 000981.XSHE  *ST银亿  0.393333
# 600568.XSHG  *ST中珠  0.391667
# 600225.XSHG  *ST松江  0.350877

# %%
#print(df_dict["002110.XSHE"])
